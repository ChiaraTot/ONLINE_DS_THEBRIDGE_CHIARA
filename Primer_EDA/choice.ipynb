# %%
import pandas as pd

# %%
dfx = pd.read_excel("./Primer_EDA/data/EU-Startups Database.xlsx")
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         2000 non-null   object
#  1   Category1     2000 non-null   object
#  2   City          2000 non-null   object
#  3   Description   1999 non-null   object
#  4   Year Founded  2000 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 78.3+ KB

# %%
df = pd.read_csv("./Primer_EDA/data/startup_data.csv")
df.head(20)
# Out:
#     Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0         1005         CA  42.358880  -71.056820    92101   c:6669
# 1          204         CA  37.238916 -121.973718    95032  c:16283
# 2         1001         CA  32.901049 -117.192656    92121  c:65620
# 3          738         CA  37.320309 -122.050040    95014  c:42668
# 4         1002         CA  37.779281 -122.419236    94105  c:65806
# 5          379         CA  37.406914 -122.090370    94043  c:22898
# 6          195         CA  37.391559 -122.070264    94041  c:16191
# 7          875         CA  38.057107 -122.513742    94901   c:5192
# 8           16         MA  42.712207  -73.203599     1267   c:1043
# 9          846         CA  37.427235 -122.145783    94306    c:498
# 10         685         CA  37.442988 -122.162413    94025   c:3949
# 11         835         CA  37.452992 -122.185098    94025   c:4829
# 12         531         KY  38.241467  -85.724511    40204  c:30290
# ...

# %%
df_star = pd.read_csv("./Primer_EDA/data/big_startup_secsees_dataset.csv")
df_star["country_code"].unique()

col_EU = european_countries_iso_alpha3 = [
    "ALB",  # Albania
    "AND",  # Andorra
    "AUT",  # Austria
    "BLR",  # Belarus
    "BEL",  # Belgium
    "BIH",  # Bosnia and Herzegovina
    "BGR",  # Bulgaria
    "HRV",  # Croatia
    "CYP",  # Cyprus
    "CZE",  # Czech Republic (Czechia)
    "DNK",  # Denmark
    "EST",  # Estonia
    "FIN",  # Finland
    "FRA",  # France
    "DEU",  # Germany
    "GRC",  # Greece
    "HUN",  # Hungary
    "ISL",  # Iceland
    "IRL",  # Ireland
    "ITA",  # Italy
    "XKX",  # Kosovo
    "LVA",  # Latvia
    "LIE",  # Liechtenstein
    "LTU",  # Lithuania
    "LUX",  # Luxembourg
    "MLT",  # Malta
    "MDA",  # Moldova
    "MCO",  # Monaco
    "MNE",  # Montenegro
    "NLD",  # Netherlands
    "MKD",  # North Macedonia
    "NOR",  # Norway
    "POL",  # Poland
    "PRT",  # Portugal
    "ROU",  # Romania
    "SMR",  # San Marino
    "SRB",  # Serbia
    "SVK",  # Slovakia
    "SVN",  # Slovenia
    "ESP",  # Spain
    "SWE",  # Sweden
    "CHE",  # Switzerland
    "TUR",  # Turkey
    "UKR",  # Ukraine
    "GBR",  # United Kingdom
    "VAT"   # Vatican City (Holy See)
]

df_EU = df_star[(df_star["country_code"].isin(col_EU))]

# %%
df_EU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10961 entries, 18 to 66364
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   permalink          10961 non-null  object
#  1   name               10961 non-null  object
#  2   homepage_url       10650 non-null  object
#  3   category_list      10633 non-null  object
#  4   funding_total_usd  10961 non-null  object
#  5   status             10961 non-null  object
#  6   country_code       10961 non-null  object
#  7   state_code         10701 non-null  object
#  8   region             10512 non-null  object
#  9   city               10512 non-null  object
#  10  funding_rounds     10961 non-null  int64
#  11  founded_at         8530 non-null   object
#  12  first_funding_at   10954 non-null  object
#  13  last_funding_at    10961 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 1.3+ MB

# %%
df_EU.region.value_counts()
# Out:
# region
# London                      2338
# Paris                        678
# Dublin                       303
# Barcelona                    276
# Berlin                       253
#                             ...
# Haywards Heath                 1
# MDA - Other                    1
# San Casciano Val Di Pesa       1
# Gardanne                       1
# Muenchen                       1
# Name: count, Length: 516, dtype: int64

# %%
df_tel.groupby(['Data_Referencia',"Nom_Companyia"])["Nombre_Vols"].sum()
# Out:
# Data_Referencia  Nom_Companyia
# 2024-01-01       Air Europa            12
#                  Air France            10
#                  Air Nostrum            4
#                  American Airlines      5
#                  British Airways        8
#                                      ...
# 2024-10-31       Vueling Airlines     333
#                  Wizz Air              22
#                  Wizz Air Malta        18
#                  easyJet Europe        36
#                  easyJet UK            14
# Name: Nombre_Vols, Length: 7483, dtype: int64

# %%
df_tel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10502 entries, 0 to 10501
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data_Referencia  10502 non-null  object
#  1   Codi_Companyia   10502 non-null  int64
#  2   Nom_Companyia    10502 non-null  object
#  3   Codi_Zona        10502 non-null  int64
#  4   Nom_Zona         10502 non-null  object
#  5   Nombre_Vols      10502 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 492.4+ KB

# %%
df_menu.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_menu.isna().sum()
#
# NameError: name 'df_menu' is not defined

# %%
df_reviews = pd.read_csv("./Primer_EDA/data/turnover.csv", encoding = 'latin-1')
df_reviews
# Out:
#             stag  event gender   age         industry  profession  \
# 0       7.030801      1      m  35.0            Banks          HR
# 1      22.965092      1      m  33.0            Banks          HR
# 2      15.934292      1      f  35.0  PowerGeneration          HR
# 3      15.934292      1      f  35.0  PowerGeneration          HR
# 4       8.410678      1      m  32.0           Retail  Commercial
# ...          ...    ...    ...   ...              ...         ...
# 1124   10.611910      0      f  41.0            Banks          HR
# 1125   10.611910      0      f  41.0            Banks          HR
# 1126  118.800821      0      f  34.0          Telecom  Accounting
# 1127   49.412731      0      f  51.0          Consult          HR
# 1128   24.837782      0      f  29.0           Retail          HR
#
#           traffic    coach head_gender greywage  way  extraversion  independ  \
# 0     rabrecNErab       no           f    white  bus           6.2       4.1
# ...

# %%
df_reviews.stag.min()
# Out:
# np.float64(0.394250513)

# %%
df_reviews.groupby('profession')['event'].sum()
# Out:
# profession
# Accounting               6
# BusinessDevelopment     16
# Commercial              15
# Consult                 16
# Engineer                11
# Finanñe                 12
# HR                     357
# IT                      25
# Law                      5
# Marketing               21
# PR                       5
# Sales                   35
# Teaching                12
# etc                     20
# manage                  15
# Name: event, dtype: int64

# %%
df_survey = pd.read_csv("./Primer_EDA/data/survey_16.csv")
df_survey
# Out:
#       Age  Gender         Country state self_employed family_history  \
# 0      37  Female   United States    IL           NaN             No
# 1      44       M   United States    IN           NaN             No
# 2      32    Male          Canada   NaN           NaN             No
# 3      31    Male  United Kingdom   NaN           NaN            Yes
# 4      31    Male   United States    TX           NaN             No
# ...   ...     ...             ...   ...           ...            ...
# 1254   26    male  United Kingdom   NaN            No             No
# 1255   32    Male   United States    IL            No            Yes
# 1256   34    male   United States    CA            No            Yes
# 1257   46       f   United States    NC            No             No
# 1258   25    Male   United States    IL            No            Yes
#
#      treatment work_interfere  size_employees remote_work tech_company  \
# ...

# %%
df_survey.tech_company.value_counts(dropna=False)
# Out:
# tech_company
# Yes    1031
# No      228
# Name: count, dtype: int64

# %%
df_survey.size_employees.value_counts(dropna=False)
# Out:
# size_employees
# 2    290
# 3    289
# 6    282
# 4    176
# 1    162
# 5     60
# Name: count, dtype: int64

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your Apify API token
# Replace '<YOUR_API_TOKEN>' with your token.
client = ApifyClient("<YOUR_API_TOKEN>")

# Prepare the Actor input
run_input = {
    "query": "react",
    "location": "barcelona",
}

# Run the Actor and wait for it to finish
run = client.actor("lexis-solutions/infojobs-net-scraper").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
print("💾 Check your data here: https://console.apify.com/storage/datasets/" + run["defaultDatasetId"])
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)

# 📚 Want to learn more 📖? Go to → https://docs.apify.com/api/client/python/docs/quick-start
